# %% [markdown]
# (methods:imaging)=
# # Imaging

# %% [markdown]
# ## Structural MRI

# %% [markdown]
# ### T1-weighted

# %% [markdown]
# #### MPRAGE

# %% [markdown]
# The three-dimensional magnetization-prepared rapid gradient-echo (3D {{MPRAGE}}) {cite}`muglerThreedimensionalMagnetizationpreparedRapid1990` is a commonly used {{T1w}} {{sMRI}} scanning sequence which optimizes the contrast between different types of tissue and provides anatomical information with outstanding detail. It is a standard sequence, also included in other contemporary large-scale neuroimaging datasets, such as the {{HCP}} {cite}`harmsExtendingHumanConnectome2018`, {{ABIDE}} II {cite}`dimartinoEnhancingStudiesConnectome2017`, and {{ADNI}} {cite}`hua3DCharacterizationBrain2008`. Unfortunately, some variation does still exist in the scanning parameters. The following table summarizes the prevalence of each distinct protocol specification in the included dataset:

# %%
from phd.methods.tables import display_mprage_counts

display_mprage_counts()
# Out:
# <style type="text/css">
# #T_1196a_  {
#   font-family: "Times New Roman", Georgia, serif;
# }
# #T_1196a_ th {
#   font-size: 1em;
#   border: 1px solid grey;
#   text-align: center;
# }
# #T_1196a_ td {
#   font-size: 1em;
#   border: 1px solid grey;
#   padding: 2px;
# }
# #T_1196a_row0_col0 {
#   font-size: 1em;
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 36.8%, transparent 36.8%);
# }
# #T_1196a_row0_col1, #T_1196a_row1_col1, #T_1196a_row3_col1, #T_1196a_row7_col1, #T_1196a_row12_col1, #T_1196a_row22_col1, #T_1196a_row24_col1, #T_1196a_row43_col1 {
#   font-size: 1em;
#   text-align: center;
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_1196a_row0_col2, #T_1196a_row1_col2, #T_1196a_row3_col2, #T_1196a_row7_col2, #T_1196a_row13_col3 {
#   font-size: 1em;
#   text-align: center;
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_1196a_row0_col3, #T_1196a_row1_col3, #T_1196a_row3_col3, #T_1196a_row7_col3, #T_1196a_row12_col3, #T_1196a_row22_col3, #T_1196a_row24_col3, #T_1196a_row26_col3, #T_1196a_row43_col3 {
#   font-size: 1em;
#   text-align: center;
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_1196a_row0_col4, #T_1196a_row1_col4, #T_1196a_row3_col4, #T_1196a_row4_col4, #T_1196a_row5_col4, #T_1196a_row7_col4, #T_1196a_row8_col4, #T_1196a_row10_col4, #T_1196a_row12_col4, #T_1196a_row13_col4, #T_1196a_row14_col1, #T_1196a_row14_col2, #T_1196a_row14_col3, #T_1196a_row15_col1, #T_1196a_row15_col2, #T_1196a_row16_col1, #T_1196a_row16_col2, #T_1196a_row18_col4, #T_1196a_row19_col4, #T_1196a_row20_col4, #T_1196a_row21_col4, #T_1196a_row22_col4, #T_1196a_row23_col4, #T_1196a_row24_col4, #T_1196a_row25_col4, #T_1196a_row26_col4, #T_1196a_row27_col4, #T_1196a_row28_col4, #T_1196a_row29_col4, #T_1196a_row30_col4, #T_1196a_row34_col4, #T_1196a_row35_col4, #T_1196a_row36_col4, #T_1196a_row40_col4, #T_1196a_row41_col4, #T_1196a_row42_col4, #T_1196a_row44_col4, #T_1196a_row45_col4, #T_1196a_row46_col4, #T_1196a_row47_col4, #T_1196a_row48_col4 {
#   font-size: 1em;
#   text-align: center;
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_1196a_row0_col5, #T_1196a_row1_col5, #T_1196a_row2_col5, #T_1196a_row3_col5, #T_1196a_row4_col5, #T_1196a_row5_col5, #T_1196a_row6_col5, #T_1196a_row7_col5, #T_1196a_row8_col5, #T_1196a_row9_col5, #T_1196a_row10_col5, #T_1196a_row11_col5, #T_1196a_row12_col5, #T_1196a_row13_col5, #T_1196a_row14_col5, #T_1196a_row15_col5, #T_1196a_row16_col5, #T_1196a_row17_col5, #T_1196a_row18_col5, #T_1196a_row19_col5, #T_1196a_row20_col5, #T_1196a_row21_col5, #T_1196a_row22_col5, #T_1196a_row23_col5, #T_1196a_row24_col5, #T_1196a_row25_col5, #T_1196a_row26_col5, #T_1196a_row27_col5, #T_1196a_row28_col5, #T_1196a_row29_col5, #T_1196a_row30_col5, #T_1196a_row31_col5, #T_1196a_row32_col5, #T_1196a_row33_col5, #T_1196a_row34_col5, #T_1196a_row35_col5, #T_1196a_row36_col5, #T_1196a_row37_col5, #T_1196a_row38_col5, #T_1196a_row39_col5, #T_1196a_row40_col5, #T_1196a_row41_col5, #T_1196a_row42_col5, #T_1196a_row43_col5, #T_1196a_row44_col5, #T_1196a_row45_col5, #T_1196a_row46_col5, #T_1196a_row47_col5, #T_1196a_row48_col5 {
#   font-size: 1em;
#   text-align: center;
# }
# #T_1196a_row1_col0 {
#   font-size: 1em;
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 23.1%, transparent 23.1%);
# }
# #T_1196a_row2_col0 {
#   font-size: 1em;
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 9.4%, transparent 9.4%);
# }
# #T_1196a_row2_col1, #T_1196a_row6_col1, #T_1196a_row9_col1, #T_1196a_row11_col1, #T_1196a_row37_col1, #T_1196a_row38_col1, #T_1196a_row39_col1 {
#   font-size: 1em;
#   text-align: center;
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_1196a_row2_col2, #T_1196a_row37_col2 {
#   font-size: 1em;
#   text-align: center;
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_1196a_row2_col3, #T_1196a_row5_col2, #T_1196a_row6_col3, #T_1196a_row9_col3, #T_1196a_row11_col3, #T_1196a_row19_col2, #T_1196a_row37_col3, #T_1196a_row38_col3, #T_1196a_row39_col3 {
#   font-size: 1em;
#   text-align: center;
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_1196a_row2_col4, #T_1196a_row6_col4, #T_1196a_row9_col4, #T_1196a_row11_col4, #T_1196a_row17_col4, #T_1196a_row37_col4, #T_1196a_row38_col4, #T_1196a_row39_col4, #T_1196a_row43_col4 {
#   font-size: 1em;
#   text-align: center;
#   background-color: #04598c;
#   color: #f1f1f1;
# }
# #T_1196a_row3_col0, #T_1196a_row4_col0 {
#   font-size: 1em;
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 6.6%, transparent 6.6%);
# }
# #T_1196a_row4_col1, #T_1196a_row5_col1, #T_1196a_row8_col1, #T_1196a_row10_col1, #T_1196a_row17_col1, #T_1196a_row18_col1, #T_1196a_row28_col1, #T_1196a_row29_col1, #T_1196a_row30_col1, #T_1196a_row34_col1, #T_1196a_row35_col1, #T_1196a_row36_col1, #T_1196a_row40_col1, #T_1196a_row41_col1, #T_1196a_row42_col1, #T_1196a_row44_col1 {
#   font-size: 1em;
#   text-align: center;
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_1196a_row4_col2, #T_1196a_row45_col2 {
#   font-size: 1em;
#   text-align: center;
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_1196a_row4_col3, #T_1196a_row5_col3, #T_1196a_row8_col3, #T_1196a_row10_col3, #T_1196a_row17_col3, #T_1196a_row18_col3, #T_1196a_row25_col3, #T_1196a_row28_col3, #T_1196a_row30_col3, #T_1196a_row35_col3, #T_1196a_row44_col3, #T_1196a_row45_col3, #T_1196a_row46_col3 {
#   font-size: 1em;
#   text-align: center;
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_1196a_row5_col0 {
#   font-size: 1em;
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 4.4%, transparent 4.4%);
# }
# #T_1196a_row6_col0 {
#   font-size: 1em;
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 3.5%, transparent 3.5%);
# }
# #T_1196a_row6_col2 {
#   font-size: 1em;
#   text-align: center;
#   background-color: #3b92c1;
#   color: #f1f1f1;
# }
# #T_1196a_row7_col0, #T_1196a_row8_col0 {
#   font-size: 1em;
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 1.7%, transparent 1.7%);
# }
# #T_1196a_row8_col2, #T_1196a_row35_col2, #T_1196a_row47_col2 {
#   font-size: 1em;
#   text-align: center;
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_1196a_row9_col0 {
#   font-size: 1em;
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 0.9%, transparent 0.9%);
# }
# #T_1196a_row9_col2 {
#   font-size: 1em;
#   text-align: center;
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_1196a_row10_col0, #T_1196a_row11_col0 {
#   font-size: 1em;
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 0.7%, transparent 0.7%);
# }
# #T_1196a_row10_col2, #T_1196a_row11_col2 {
#   font-size: 1em;
#   text-align: center;
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_1196a_row12_col0 {
#   font-size: 1em;
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 0.4%, transparent 0.4%);
# }
# #T_1196a_row12_col2, #T_1196a_row15_col3, #T_1196a_row15_col4, #T_1196a_row33_col3, #T_1196a_row33_col4, #T_1196a_row48_col1 {
#   font-size: 1em;
#   text-align: center;
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_1196a_row13_col0, #T_1196a_row14_col0, #T_1196a_row15_col0, #T_1196a_row16_col0 {
#   font-size: 1em;
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 0.3%, transparent 0.3%);
# }
# #T_1196a_row13_col1 {
#   font-size: 1em;
#   text-align: center;
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_1196a_row13_col2 {
#   font-size: 1em;
#   text-align: center;
#   background-color: #4897c4;
#   color: #f1f1f1;
# }
# #T_1196a_row14_col4, #T_1196a_row16_col4, #T_1196a_row31_col4, #T_1196a_row32_col4 {
#   font-size: 1em;
#   text-align: center;
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_1196a_row16_col3 {
#   font-size: 1em;
#   text-align: center;
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_1196a_row17_col0, #T_1196a_row18_col0, #T_1196a_row1

# %% [markdown]
# ### Diffusion-weighted MRI

# %% [markdown]
# ## Functional MRI

# %% [markdown]
# ### rs-fMRI
