# %% [markdown]
# (methods:imaging)=
# # Imaging

# %% [markdown]
# ## Structural MRI

# %% [markdown]
# ### T1-weighted

# %% [markdown]
# #### MPRAGE

# %% [markdown]
# The three-dimensional magnetization-prepared rapid gradient-echo (3D {{MPRAGE}}) {cite}`muglerThreedimensionalMagnetizationpreparedRapid1990` is a commonly used {{T1w}} {{sMRI}} scanning sequence which optimizes the contrast between different types of tissue and provides anatomical information with outstanding detail. It is a standard sequence, also included in other contemporary large-scale neuroimaging datasets, such as the {{HCP}} {cite}`harmsExtendingHumanConnectome2018`, {{ABIDE}} II {cite}`dimartinoEnhancingStudiesConnectome2017`, and {{ADNI}} {cite}`hua3DCharacterizationBrain2008`. Unfortunately, some variation does still exist in the scanning parameters. The following table summarizes the prevalence of each distinct protocol specification in the included dataset:

# %%
from phd.methods.tables import display_mprage_counts

display_mprage_counts()
# Out:
# <style type="text/css">
# #T_094a5_ th {
#   font-size: 10pt;
# }
# #T_094a5_ td {
#   font-size: 10pt;
# }
# #T_094a5_row0_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
# }
# #T_094a5_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 13.8%, transparent 13.8%);
# }
# #T_094a5_row2_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 9.6%, transparent 9.6%);
# }
# #T_094a5_row3_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 6.3%, transparent 6.3%);
# }
# #T_094a5_row4_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 5.1%, transparent 5.1%);
# }
# #T_094a5_row5_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 2.4%, transparent 2.4%);
# }
# #T_094a5_row6_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 1.2%, transparent 1.2%);
# }
# #T_094a5_row7_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 1.0%, transparent 1.0%);
# }
# #T_094a5_row8_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 0.9%, transparent 0.9%);
# }
# #T_094a5_row9_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 0.6%, transparent 0.6%);
# }
# #T_094a5_row10_col0, #T_094a5_row11_col0, #T_094a5_row12_col0, #T_094a5_row13_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 0.4%, transparent 0.4%);
# }
# #T_094a5_row14_col0, #T_094a5_row15_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 0.3%, transparent 0.3%);
# }
# #T_094a5_row16_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 0.2%, transparent 0.2%);
# }
# #T_094a5_row17_col0, #T_094a5_row18_col0, #T_094a5_row19_col0, #T_094a5_row20_col0, #T_094a5_row21_col0, #T_094a5_row22_col0, #T_094a5_row23_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 0.1%, transparent 0.1%);
# }
# #T_094a5_row24_col0, #T_094a5_row25_col0, #T_094a5_row26_col0, #T_094a5_row27_col0, #T_094a5_row28_col0, #T_094a5_row29_col0, #T_094a5_row30_col0, #T_094a5_row31_col0, #T_094a5_row32_col0, #T_094a5_row33_col0, #T_094a5_row34_col0, #T_094a5_row35_col0, #T_094a5_row36_col0, #T_094a5_row37_col0, #T_094a5_row38_col0, #T_094a5_row39_col0, #T_094a5_row40_col0, #T_094a5_row41_col0, #T_094a5_row42_col0, #T_094a5_row43_col0, #T_094a5_row44_col0 {
#   width: 10em;
#   height: 80%;
# }
# </style>
# <table id="T_094a5_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Count</th>
#       <th class="col_heading level0 col1" >Repetition Time (TR)</th>
#       <th class="col_heading level0 col2" >Echo Time (TE)</th>
#       <th class="col_heading level0 col3" >Inversion Time (TI)</th>
#       <th class="col_heading level0 col4" >Flip Angle</th>
#       <th class="col_heading level0 col5" >Slice Thickness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_094a5_row0_col0" class="data row0 col0" >1562</td>
#       <td id="T_094a5_row0_col1" class="data row0 col1" >2400</td>
#       <td id="T_094a5_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_094a5_row0_col3" class="data row0 col3" >1000</td>
#       <td id="T_094a5_row0_col4" class="data row0 col4" >8</td>
#       <td id="T_094a5_row0_col5" class="data row0 col5" >1</td>
#     </tr>
#     <tr>
#       <td id="T_094a5_row1_col0" class="data row1 col0" >217</td>
#       <td id="T_094a5_row1_col1" class="data row1 col1" >2530</td>
#       <td id="T_094a5_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_094a5_row1_col3" class="data row1 col3" >1100</td>
#       <td id="T_094a5_row1_col4" class="data row1 col4" >7</td>
#       <td id="T_094a5_row1_col5" class="data row1 col5" >1</td>
#     </tr>
#     <tr>
#       <td id="T_094a5_row2_col0" class="data row2 col0" >151</td>
#       <td id="T_094a5_row2_col1" class="data row2 col1" >1750</td>
#       <td id="T_094a5_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_094a5_row2_col3" class="data row2 col3" >900</td>
#       <td id="T_094a5_row2_col4" class="data row2 col4" >8</td>
#       <td id="T_094a5_row2_col5" class="data row2 col5" >1</td>
#     </tr>
#     <tr>
#       <td id="T_094a5_row3_col0" class="data row3 col0" >100</td>
#       <td id="T_094a5_row3_col1" class="data row3 col1" >1750</td>
#       <td id="T_094a5_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_094a5_row3_col3" class="data row3 col3" >900</td>
#       <td id="T_094a5_row3_col4" class="data row3 col4" >8</td>
#       <td id="T_094a5_row3_col5" class="data row3 col5" >1</td>
#     </tr>
#     <tr>
#       <td id="T_094a5_row4_col0" class="data row4 col0" >80</td>
#       <td id="T_094a5_row4_col1" class="data row4 col1" >2530</td>
#       <td id="T_094a5_row4_col2" class="data row4 col2" >3</td>
#       <td id="T_094a5_row4_col3" class="data row4 col3" >1100</td>
#       <td id="T_094a5_row4_col4" class="data row4 col4" >7</td>
#       <td id="T_094a5_row4_col5" class="data row4 col5" >1</td>
#     </tr>
#     <tr>
#       <td id="T_094a5_row5_col0" class="data row5 col0" >38</td>
#       <td id="T_094a5_row5_col1" class="data row5 col1" >1750</td>
#       <td id="T_094a5_row5_col2" class="data row5 col2" >3</td>
#       <td id="T_094a5_row5_col3" class="data row5 col3" >900</td>
#       <td id="T_094a5_row5_col4" class="data row5 col4" >8</td>
#       <td id="T_094a5_row5_col5" class="data row5 col5" >1</td>
#     </tr>
#     <tr>
#       <td id="T_094a5_row6_col0" class="data row6 col0" >20</td>
#       <td id="T_094a5_row6_col1" class="data row6 col1" >2530</td>
#       <td id="T_094a5_row6_col2" class="data row6 col2" >3</td>
#       <td id="T_094a5_row6_col3" class="data row6 col3" >1100</td>
#       <td id="T_094a5_row6_col4" class="data row6 col4" >7</td>
#       <td id="T_094a5_row6_col5" class="data row6 col5" >1</td>
#     </tr>
#     <tr>
#       <td id="T_094a5_row7_col0" class="data row7 col0" >16</td>
#       <td id="T_094a5_row7_col1" class="data row7 col1" >1750</td>
#       <td id="T_094a5_row7_col2" class="data row7 col2" >2</td>
#       <td id="T_094a5_row7_col3" class="data row7 col3" >900</td>
#       <td id="T_094a5_row7_col4" class="data row7 col4" >8</td>
#       <td id="T_094a5_row7_col5" class="data row7 col5" >1</td>
#     </tr>
#     <tr>
#       <td id="T_094a5_row8_col0" class="data row8 col0" >15</td>
#       <td id="T_094a5_row8_col1" class="data row8 col1" >2530</td>
#       <td id="T_094a5_row8_col2" class="data row8 col2" >2</td>
#       <td id="T_094a5_row8_col3" class="data row8 col3" >1100</td>
#       <td id="T_094a5_row8_col4" class="data row8 col4" >7</td>
#       <td id="T_094a5_row8_col5" class="data row8 col5" >1</td>
#     </tr>
#     <tr>
#       <td id="T_094a5_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_094a5_row9_col1" class="data row9 col1" >2400</td>
#       <td id="T_094a5_row9_col2" class="data row9 col2" >2</td>
#       <td id="T_094a5_row9_col3" class="data row9 col3" >1000</td>
#       <td id="T_094a5_row9_col4" class="data row9 col4" >8</td>
#       <td id="T_094a5_row9_col5" class="data row9 col5" >1</td>
#     </tr>
#     <tr>
#       <td id="T_094a5_row10_col0" class="data row10 col0" >8</td>
#       <td id="T_094a5_row10_col1" class="data row10 col1" >2000</td>
#       <td id="T_094a5_row10_col2" class="data row10 col2" >3</td>
#       <td id="T_094a5_row10_col3" class="data row10 col3" >1010</td>
#       <td id="T_094a5_row10_col4" class="data row10 col4" >8</td>
#       <td id="T_094a5_row10_col5" class="data row10 col5" >0</td>
#     </tr>
#     <tr>
#       <td id="T_094a5_row11_col0" class="data row11 col0" >8</td>
#       <td id="T_094a5_row11_col1" class="data row11 col1" >4000</td>
#       <td id="T_094a5_row11_col2" class="data row11 col2" >4</td>
#       <td id="T_094a5_row11_col3" class="data row11 col3" >2180</td>
#       <td id="T_094a5_row11_col4" class="data row11 col4" >5</td>
#       <td id="T_094a5_row11_col5" class="data row11 col5" >1</td>
#     </tr>
#     <tr>
#       <td id="T_094a5_row12_col0" class="data row12 col0" >8</td>
#       <td id="T_094a5_row1

# %% [markdown]
# ### Diffusion-weighted MRI

# %% [markdown]
# ## Functional MRI

# %% [markdown]
# ### rs-fMRI
